# %%
# Import external script
# %run models.py

# %%
# Import data from CSV
fdata = pd.read_csv('data_histories.csv', index_col="dp_folio")
fdata.head()
# Out:
#          id_sexo  Aedad  AAedad Apuesto id_gestud  AIMC  fuma  fuma_act  \
# dp_folio
# 1              F     51       6   Admin    CarTec     4     1         3
# 2              F     38       4     Sec      Bach     3     2        -1
# 3              F     34       3     Int       Sec     5     1         1
# 4              M     63       8     Jef    CarTec     4     2        -1
# 5              M     42       4      EM       Sec     3     1         2
#
#           ejer_act  ejer1  ...  locout5  locout10  locout20  locout30  \
# dp_folio                   ...
# 1                0      2  ...        1         1         1         1
# 2                0      0  ...        0         0         0         0
# 3                0      0  ...        1        -1        -1        -1
# 4                2      2  ...        0         0         0        -1
# 5                2      2  ...        0         0         0         0
#
#           rest_act  rest1  rest5  rest10  rest20  rest30
# dp_folio
# 1                0      0      0       0       0       0
# 2                1      3      0       0       0       0
# 3                0      0      0      -1      -1      -1
# 4                0      0      0       0       0       0
# 5                0      0      0       0       0       0
#
# [5 rows x 72 columns]

# %%
pm = ProbModel()

# %%
# Clusterize between obese and non obese
obesity = {0:[1,2,3], 1:[4,5,6]}
ndata = pm.clusterize_discrete("AIMC", obesity, "obesity", fdata)

# Clusterize excercise features
ejer = {"A":"greatereq_than(2.5)", "B":"less_than(2.5)"}
ndata = pm.clusterize_continuous("ejer_act", ejer, "ejer0B", ndata)
ndata = pm.clusterize_continuous("ejer1", ejer, "ejer1B", ndata)
ndata = pm.clusterize_continuous("ejer5", ejer, "ejer5B", ndata)
ndata = pm.clusterize_continuous("ejer10", ejer, "ejer10B", ndata)
ndata = pm.clusterize_continuous("ejer20", ejer, "ejer20B", ndata)
ndata = pm.clusterize_continuous("ejer30", ejer, "ejer30B", ndata)

# Clusterize weight features
condi = {"A":[4,5], "B":[1,2,3]}
ndata = pm.clusterize_discrete("condi_act", condi, "condi0B", ndata)
ndata = pm.clusterize_discrete("condi1", condi, "condi1B", ndata)
ndata = pm.clusterize_discrete("condi5", condi, "condi5B", ndata)
ndata = pm.clusterize_discrete("condi10", condi, "condi10B", ndata)
ndata = pm.clusterize_discrete("condi20", condi, "condi20B", ndata)
ndata = pm.clusterize_discrete("condi30", condi, "condi30B", ndata)

ndata = pm.group_list_of_variables(["ejer0B", "ejer1B", "ejer5B", "ejer10B", "ejer20B", "ejer30B"], "ejerHistory", ndata)
ndata = pm.group_list_of_variables(["condi0B", "condi1B", "condi5B", "condi10B", "condi20B", "condi30B"], "condiHistory", ndata)

# %%
selected_features = ["ejer0B", "ejer1B", "ejer5B", "ejer10B", "ejerHistory", "obesity"]
query_features = ["ejer0B", "ejer1B", "ejer5B", "ejer10B"]
sdata = ndata[selected_features]
sdata.head()
# Out:
#          ejer0B ejer1B ejer5B ejer10B ejerHistory  obesity
# dp_folio
# 1             B      B      B       B      BBBBBA        1
# 2             B      B      A       A      BBAAAB        0
# 3             B      B      B       A      BBBANN        1
# 4             B      B      A       A      BBAAAA        1
# 5             B      B      B       B      BBBBBB        0

# %%
rdata = sdata[(ndata.ejer20B != "N") & (ndata.ejer10B != "N") & (ndata.ejer5B != "N") & (ndata.ejer1B != "N") & (ndata.ejer0B != "N")]
rdata
# Out:
#          ejer0B ejer1B ejer5B ejer10B ejerHistory  obesity
# dp_folio
# 1             B      B      B       B      BBBBBA        1
# 2             B      B      A       A      BBAAAB        0
# 4             B      B      A       A      BBAAAA        1
# 5             B      B      B       B      BBBBBB        0
# 6             A      B      B       B      ABBBBB        0
# ...         ...    ...    ...     ...         ...      ...
# 1076          B      B      B       A      BBBAAA        1
# 1077          A      A      B       B      AABBBA        0
# 1078          B      A      A       A      BAAAAA        0
# 1079          B      B      B       B      BBBBBB        0
# 1080          B      B      A       A      BBAAAA        0
#
# [939 rows x 6 columns]

# %%
validation = Validation(GNB())

# %%
queries = {"ejer0B": ["A", "B", "N"]
          }

# %%
validation.run_cv(rdata, queries, "obesity", 1, 5, "Test plot")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4735             try:
# -> 4736                 return libindex.get_value_box(s, key)
#    4737             except IndexError:
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_box()
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.validate_indexer()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-84-37e667f49f51> in <module>
# ----> 1 validation.run_cv(rdata, queries, "obesity", 1, 5, "Test plot")
#
# ~/mcc/histories/models.py in run_cv(self, X, qF, cF, cC, folds, plot_name)
#     500                 test = test.append(X.loc[name])
#     501
# --> 502             self.model.train(qF, cF, cC, train)
#     503             self.model.predict(test)
#     504             Yprob = self.model.get_predicted_scores()
#
# ~/mcc/histories/models.py in train(self, queries, classFeature, classCategory, Xt)
#     440         self.classCategory = classCategory
#     441         if type(self.queries) is dict:
# --> 442             self.scores_dictionary = self.get_scores_from_featlist_and_catlist(self.queries, self.classFeature, self.classCategory, Xt)
#     443         elif type(self.queries) is list:
#     444             self.scores_dictionary = self.get_scores_from_featlist(self.queries, self.classFeature, self.classCategory, Xt)
#
# ~/mcc/histories/models.py in get_scores_from_featlist_and_catlist(self, queries, classFeature, classCategory, data)
#     282         scores = {}
#     283         for feature in queries:
# --> 284             scores[feature] = self.get_scores_from_feature_and_catlist(feature, queries[feature], classFeature, classCategory, data)
#     285         return scores
#     286
#
# ~/mcc/histories/models.py in get_scores_from_feature_and_catlist(self, feature, catlist, classFeature, classCategory, data)
#     290         for category in catlist:
#     291             #scores.append(get_score(feature, category, classFeature, classCategory, data))
# --> 292             scores[category] = self.get_score(feature, category, classFeature, classCategory, data)
#     293         return scores
#     294
#
# ~/mcc/histories/models.py in get_score(self, feature, category, classFeature, classCategory, data)
#     228     def get_score(self, feature, category, classFeature, classCategory, data):
#     229         n = len(data)
# --> 230         nx = self.get_nx(feature, category, data)
#     231         nc = self.get_nx(classFeature, classCategory, data)
#     232         ncx = self.get_ncx(feature, category, classFeature, classCategory, data)
#
# ~/mcc/histories/models.py in get_nx(self, feature, category, data)
#     103         count = 0
#     104         for index in data.index:
# --> 105             if data.loc[index][feature] == category:
#     106                 count = count + 1
#     107             elif self.match_structure(data.loc[index][feature], category):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#    1066         key = com.apply_if_callable(key, self)
#    1067         try:
# -> 1068             result = self.index.get_value(self, key)
#    1069
#    1070             if not is_scalar(result):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4742                     raise InvalidIndexError(key)
#    4743                 else:
# -> 4744                     raise e1
#    4745             except Exception:  # pragma: no cover
#    4746                 raise e1
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4728         k = self._convert_scalar_indexer(k, kind="getitem")
#    4729         try:
# -> 4730             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4731         except KeyError as e1:
#    4732             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'condi0B'
